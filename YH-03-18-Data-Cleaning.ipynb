# %%
import pandas as pd

data = pd.read_csv('train_users_2.csv')

# %%
data.shape
# Out:
# (213451, 16)

# %%
data["date_first_booking"] = pd.to_datetime(data["date_first_booking"], format='%Y-%m-%d', errors="coerce")
data['date_first_booking_year'] = data['date_first_booking'].dt.year
data['date_first_booking_month'] = data['date_first_booking'].dt.month

# %%
data.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaT
# 1  820tgsjxq7           2011-05-25          20090523174809                NaT
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
# ...

# %% [markdown]
# # Yearly user distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data.groupby(['date_first_booking_year']).size().plot(kind = 'barh')
plt.xlabel('Count')
plt.ylabel('Year')
plt.title('Yearly User First Booking Distribution')
plt.show()

# %% [markdown]
# # Time Series Plot for the date_account_created

# %%
plt.subplot(3, 2, 1)
data[data['date_first_booking_year']==2010].groupby(['date_first_booking_month']).size().plot(kind='line',fontsize=8,figsize=(11,8))
plt.xlabel('Month',fontsize=11)
plt.title('2010',fontsize=11)

plt.subplot(3, 2, 2)
data[data['date_first_booking_year']==2011].groupby(['date_first_booking_month']).size().plot(kind='line',fontsize=8,figsize=(11,8))
plt.xlabel('Month',fontsize=11)
plt.title('2011',fontsize=11)

plt.subplot(3, 2, 3)
data[data['date_first_booking_year']==2012].groupby(['date_first_booking_month']).size().plot(kind='line',fontsize=8,figsize=(11,8))
plt.xlabel('Month',fontsize=11)
plt.title('2012',fontsize=11)

plt.subplot(3, 2, 4)
data[data['date_first_booking_year']==2013].groupby(['date_first_booking_month']).size().plot(kind='line',fontsize=8,figsize=(11,8))
plt.xlabel('Month',fontsize=11)
plt.title('2013',fontsize=11)

plt.subplot(3, 2, 5)
data[data['date_first_booking_year']==2014].groupby(['date_first_booking_month']).size().plot(kind='line',fontsize=8,figsize=(11,8))
plt.xlabel('Month',fontsize=11)
plt.title('2014',fontsize=11)

plt.subplot(3, 2, 6)
data[data['date_first_booking_year']==2015].groupby(['date_first_booking_month']).size().plot(kind='line',fontsize=8,figsize=(11,8))
plt.xlabel('Month',fontsize=11)
plt.title('2015',fontsize=11)
plt.tight_layout()
plt.show()

# %%
set(data.gender)
# Out:
# {'-unknown-', 'FEMALE', 'MALE', 'OTHER'}

# %%
data.groupby(['gender']).size().plot(kind='bar',fontsize=8,figsize=(11,8))
plt.xlabel('gender',fontsize=11)
plt.title('gender',fontsize=11)
plt.show()

# %%
data.dtypes
# Out:
# id                                  object
# date_account_created                object
# timestamp_first_active               int64
# date_first_booking          datetime64[ns]
# gender                              object
# age                                float64
# signup_method                       object
# signup_flow                          int64
# language                            object
# affiliate_channel                   object
# affiliate_provider                  object
# first_affiliate_tracked             object
# signup_app                          object
# first_device_type                   object
# first_browser                       object
# country_destination                 object
# date_first_booking_year            float64
# date_first_booking_month           float64
# dtype: object

# %%
import numpy as np
data.gender.replace('-unknown-', np.nan, inplace=True)

# %%
data.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaT
# 1  820tgsjxq7           2011-05-25          20090523174809                NaT
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#    gender   age signup_method  signup_flow language affiliate_channel  \
# 0     NaN   NaN      facebook            0       en            direct
# 1    MALE  38.0      facebook            0       en               seo
# 2  FEMALE  56.0         basic            3       en            direct
# 3  FEMALE  42.0      facebook            0       en            direct
# 4     NaN  41.0         basic            0       en            direct
#
# ...

# %%
users_nan = (data.isnull().sum() / data.shape[0]) * 100
users_nan[users_nan > 0].drop('country_destination')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-df98216e5ef9> in <module>()
#       1 users_nan = (data.isnull().sum() / data.shape[0]) * 100
# ----> 2 users_nan[users_nan > 0].drop('country_destination')
#
# /Users/tommyhuang/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/tommyhuang/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
users_nan
# Out:
# id                           0.000000
# date_account_created         0.000000
# timestamp_first_active       0.000000
# date_first_booking          58.347349
# gender                      44.829024
# age                         41.222576
# signup_method                0.000000
# signup_flow                  0.000000
# language                     0.000000
# affiliate_channel            0.000000
# affiliate_provider           0.000000
# first_affiliate_tracked      2.841402
# signup_app                   0.000000
# first_device_type            0.000000
# first_browser                0.000000
# country_destination          0.000000
# date_first_booking_year     58.347349
# date_first_booking_month    58.347349
# dtype: float64

# %%
testdata = pd.read_csv('test_users.csv')

# %%
testdata.head()
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# ...

# %%
m = pd.concat((data, testdata), axis=0, ignore_index=True)

# %%
data.age.describe()
# Out:
# /Users/tommyhuang/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    125461.000000
# mean         49.668335
# std         155.666612
# min           1.000000
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max        2014.000000
# Name: age, dtype: float64

# %%
data1 = data[(data.age<=122) & (data.age>=18)] #Removed some rows with non-sense age value

# %%
(data1.isnull().sum() / data.shape[0]) * 100
# Out:
# id                           0.000000
# date_account_created         0.000000
# timestamp_first_active       0.000000
# date_first_booking          26.417304
# gender                       7.851919
# age                          0.000000
# signup_method                0.000000
# signup_flow                  0.000000
# language                     0.000000
# affiliate_channel            0.000000
# affiliate_provider           0.000000
# first_affiliate_tracked      0.925739
# signup_app                   0.000000
# first_device_type            0.000000
# first_browser                0.000000
# country_destination          0.000000
# date_first_booking_year     26.417304
# date_first_booking_month    26.417304
# dtype: float64

# %%
data.loc[data.age > 99, 'age'] = np.nan
data.loc[data.age < 18, 'age'] = np.nan

# %%
data.shape
# Out:
# (213451, 16)

# %%
(data.isnull().sum() / data.shape[0]) * 100
# Out:
# id                          0.000000
# date_account_created        0.000000
# timestamp_first_active      0.000000
# date_first_booking         58.347349
# gender                      0.000000
# age                         0.000000
# signup_method               0.000000
# signup_flow                 0.000000
# language                    0.000000
# affiliate_channel           0.000000
# affiliate_provider          0.000000
# first_affiliate_tracked     2.841402
# signup_app                  0.000000
# first_device_type           0.000000
# first_browser               0.000000
# country_destination         0.000000
# dtype: float64

# %%
data[data.date_first_booking.isnull()]
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28          20090319043255
# 1       820tgsjxq7           2011-05-25          20090523174809
# 11      om1ss59ys8           2010-01-05          20100105051812
# 13      dy3rgx56cu           2010-01-05          20100105083259
# 14      ju3h98ch3w           2010-01-07          20100107055820
# 16      2dwbwkx056           2010-01-07          20100107215125
# 18      cxlg85pg1r           2010-01-08          20100108015641
# 23      jha93x042q           2010-01-11          20100111224015
# 24      7i49vnuav6           2010-01-11          20100111230808
# 26      bjg0m5otl3           2010-01-12          20100112155420
# 31      pggg2sj27u           2010-01-14          20100114060757
# 32      mo2v5h3nti           2010-01-14          20100114084926
# 33      qthj88nnc7           2010-01-14          20100114175209
# 34      x9gnxoun57           2010-01-15          20100115055053
# ...

# %%
set(data.country_destination)
# Out:
# {'AU', 'CA', 'DE', 'ES', 'FR', 'GB', 'IT', 'NDF', 'NL', 'PT', 'US', 'other'}

# %%
data.first_browser.replace('-unknown-', np.nan, inplace=True)

# %%
data.to_csv('CleanedAirBnb.csv',encoding = 'utf-8')

# %%
k=pd.read_csv('CleanedAirBnb.csv')

# %%
k.head()
# Out:
#    Unnamed: 0          id date_account_created  timestamp_first_active  \
# 0           0  gxn3p5htnn           2010-06-28          20090319043255
# 1           1  820tgsjxq7           2011-05-25          20090523174809
# 2           2  4ft3gnwmtx           2010-09-28          20090609231247
# 3           3  bjjt8pjhuk           2011-12-05          20091031060129
# 4           4  87mebub9p4           2010-09-14          20091208061105
#
#   date_first_booking  gender  age signup_method  signup_flow language  \
# 0                NaN     NaN   99      facebook            0       en
# 1                NaN    MALE   99      facebook            0       en
# 2         2010-08-02  FEMALE   99         basic            3       en
# 3         2012-09-08  FEMALE   99      facebook            0       en
# 4         2010-02-18     NaN   99         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# ...
